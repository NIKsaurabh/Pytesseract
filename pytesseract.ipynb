# %%
#Importing libraries
import pytesseract
from PIL import Image

# %%
#loading image
img = Image.open('Images/1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x266 at 0x7FAF7C8D2490>

# %%
#if text is in hindi, then we can extract it using following code
#print(pytesseract.image_to_string(img, lang='hin'))

# %%
#Extracting english strings and numbers
print(pytesseract.image_to_string(img))
# Out:
# The mind is like a sheet
# of white paper in this,
# that the impression it
# receivest oftenest, and
#
# retains the longest,
# are black ones.
